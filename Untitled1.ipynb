# %% [markdown]
# <a href="https://colab.research.google.com/github/esraevrim/App_pet/blob/master/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi

# !pip install torch torchvision torchaudio
# !pip install opencv-python matplotlib
# !pip install 'git+https://github.com/facebookresearch/segment-anything-2.git'

import os
checkpoint_dir = "checkpoints"
os.makedirs(checkpoint_dir, exist_ok=True)
# !wget -P {checkpoint_dir} https://dl.fbaipublicfiles.com/segment_anything_2/072824/sam2_hiera_large.pt
# Out:
# Thu Mar 26 12:22:57 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA L4                      Off |   00000000:00:03.0 Off |                    0 |
# | N/A   40C    P8             16W /   72W |       0MiB /  23034MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !wget -O trafik_video.mp4 "https://dn710901.ca.archive.org/0/items/0002201705192/0002-20170519-2.mp4"
# Out:
# --2026-03-26 11:55:56--  https://dn710901.ca.archive.org/0/items/0002201705192/0002-20170519-2.mp4
# Resolving dn710901.ca.archive.org (dn710901.ca.archive.org)... 204.62.248.112
# Connecting to dn710901.ca.archive.org (dn710901.ca.archive.org)|204.62.248.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9185052035 (8.6G) [video/mp4]
# Saving to: ‘trafik_video.mp4’
#
# trafik_video.mp4    100%[===================>]   8.55G  21.0MB/s    in 12m 44s
#
# 2026-03-26 12:08:42 (11.5 MB/s) - ‘trafik_video.mp4’ saved [9185052035/9185052035]

# %%
# !pip install decord

# %%
import torch
from sam2.build_sam import build_sam2_video_predictor

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

sam2_checkpoint = "checkpoints/sam2_hiera_large.pt"
model_cfg = "sam2_hiera_l.yaml"

predictor = build_sam2_video_predictor(model_cfg, sam2_checkpoint, device=device)
# Out:
# Using device: cuda

# %%
import cv2
import os

# Create the directory again
video_dir = "video_frames"
os.makedirs(video_dir, exist_ok=True)

# Read the downloaded video
cap = cv2.VideoCapture("trafik_video.mp4")
frame_idx = 0
max_frames = 500 # Keep it short for testing

print("Extracting frames... please wait.")

while frame_idx < max_frames:
    ret, frame = cap.read()
    if not ret:
        break
    # Save each frame as a .jpg file
    frame_name = os.path.join(video_dir, f"{frame_idx:05d}.jpg")
    cv2.imwrite(frame_name, frame)
    frame_idx += 1

cap.release()
print(f"Done! {frame_idx} frames saved in '{video_dir}' folder.")
# Out:
# Extracting frames... please wait.
# Done! 500 frames saved in 'video_frames' folder.

# %%
import matplotlib.pyplot as plt
from PIL import Image
import os

# Define the frame numbers we want to extract
# Since we already extracted 500 frames, let's just use those.
# Ensure video_dir is correctly set to 'video_frames'
video_dir = "video_frames"

# Use the first frame from the directory we created
frame_names = [f for f in os.listdir(video_dir) if f.endswith(".jpg")]
frame_names.sort()
first_frame_path = os.path.join(video_dir, frame_names[0])

# Open and display the first frame with axes
img = Image.open(first_frame_path)
plt.figure(figsize=(15, 10))
plt.imshow(img)
plt.title("First Frame - Find your target coordinates")
plt.axis('on') # Show axes (x and y) to pick a point
plt.show()
# Out:
# <div id='64394611-24df-4df7-abe7-14c5307c126d'></div>

# %%
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np

# Load first frame
img = Image.open("video_frames/00000.jpg")
img_array = np.array(img)

# Create a high-res figure
fig, ax = plt.subplots(figsize=(30, 20)) # Çok büyük yaptık ki koordinatlar net gözüksün
ax.imshow(img_array)

# Add grid lines
ax.set_xticks(np.arange(0, img_array.shape[1], 100))
ax.set_yticks(np.arange(0, img_array.shape[0], 100))
ax.grid(color='white', linestyle='--', linewidth=1, alpha=0.8)

# Save the image instead of showing it
plt.savefig("koordinat_bulma.jpg", bbox_inches='tight', dpi=100)
plt.close()

print("Image created! click on 'koordinat_bulma.jpg' ")
# Out:
# <div id='5f8b6914-3301-4eac-aa01-f8cfd9bbd9d0'></div>
# Image created! click on 'koordinat_bulma.jpg'

# %%
inference_state = predictor.init_state(video_path="video_frames")
# Out:
# frame loading (JPEG): 100%|██████████| 500/500 [01:15<00:00,  6.64it/s]

# %%
target_points = [[1815, 1045]]
target_labels = [1]

ann_frame_index = 0
ann_obj_id = 1

_, out_obj_ids, out_mask_logits = predictor.add_new_points(
    inference_state=inference_state,
    frame_idx=ann_frame_index,
    obj_id=ann_obj_id,
    points=target_points,
    labels=target_labels,
)

print(f"Point added successfully to Object ID: {out_obj_ids}")
# Out:
# Point added successfully to Object ID: [1]
# /usr/local/lib/python3.12/dist-packages/sam2/sam2_video_predictor.py:786: UserWarning: cannot import name '_C' from 'sam2' (/usr/local/lib/python3.12/dist-packages/sam2/__init__.py)
#
# Skipping the post-processing step due to the error above. You can still use SAM 2 and it's OK to ignore the error above, although some post-processing functionality may be limited (which doesn't affect the results in most cases; see https://github.com/facebookresearch/sam2/blob/main/INSTALL.md).
#   pred_masks_gpu = fill_holes_in_mask_scores(

# %%
video_segments = {}

for out_frame_idx, out_obj_ids, out_mask_logits in predictor.propagate_in_video(inference_state):
    video_segments[out_frame_idx] = {
        out_obj_id: (out_mask_logits[i] > 0.0).cpu().numpy()
        for i, out_obj_id in enumerate(out_obj_ids)
    }

print("Propagation complete! Ready to save the video.")
# Out:
# propagate in video: 100%|██████████| 500/500 [03:20<00:00,  2.49it/s]
# Propagation complete! Ready to save the video.

# %%
import cv2
import numpy as np
from PIL import Image

# Output video settings
output_video_path = "sam2_tracked_video_try2.mp4"
frame_names = [f for f in os.listdir(video_dir) if f.endswith(".jpg")]
frame_names.sort()

# Get dimensions from the first frame
first_frame = cv2.imread(os.path.join(video_dir, frame_names[0]))
height, width, _ = first_frame.shape

# Initialize Video Writer
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_video_path, fourcc, 30.0, (width, height))

print("Video being created, please wait...")

for frame_idx, frame_name in enumerate(frame_names):
    # Read the original frame
    frame_path = os.path.join(video_dir, frame_name)
    frame = cv2.imread(frame_path)

    if frame_idx in video_segments:
        for obj_id, mask in video_segments[frame_idx].items():
            # Create a colored mask (e.g., Green)
            # mask is a boolean array, we convert it to uint8
            color = np.array([0, 255, 0], dtype='uint8')

            mask_bool = mask.reshape(height, width)
            frame[mask_bool] = frame[mask_bool] * 0.5 + color * 0.5

    out.write(frame)

out.release()
print(f"Done! Video saved to: {output_video_path}")
# Out:
# Video being created, please wait...
# Done! Video saved to: sam2_tracked_video_try2.mp4

# %%
target_x = 1950
target_y = 1150

predictor.reset_state(inference_state)

predictor.add_new_points(
    inference_state=inference_state,
    frame_idx=0,
    obj_id=1,
    points=[[target_x, target_y]],
    labels=[1],
)

video_segments = {}
print("Tracking (Propagation) is starting, please wait...")

for out_frame_idx, out_obj_ids, out_mask_logits in predictor.propagate_in_video(inference_state):
    video_segments[out_frame_idx] = {
        out_obj_id: (out_mask_logits[i] > 0.0).cpu().numpy()
        for i, out_obj_id in enumerate(out_obj_ids)
    }

print("Done! P tracked succesfully.")
# Out:
# /usr/local/lib/python3.12/dist-packages/sam2/sam2_video_predictor.py:786: UserWarning: cannot import name '_C' from 'sam2' (/usr/local/lib/python3.12/dist-packages/sam2/__init__.py)
#
# Skipping the post-processing step due to the error above. You can still use SAM 2 and it's OK to ignore the error above, although some post-processing functionality may be limited (which doesn't affect the results in most cases; see https://github.com/facebookresearch/sam2/blob/main/INSTALL.md).
#   pred_masks_gpu = fill_holes_in_mask_scores(
# Tracking (Propagation) is starting, please wait...
# propagate in video: 100%|██████████| 500/500 [03:17<00:00,  2.54it/s]
# Done! P tracked succesfully.
